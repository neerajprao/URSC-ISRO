# %%
from penalty_wrapper import load_board_config, compute_penalty
import numpy as np

cfg = load_board_config('newobj.json')
n = cfg['num_components']
x = np.zeros(n)   # all at origin
y = np.zeros(n)
print(compute_penalty(x, y, cfg))   # huge penalty due to overlaps
# Out:
# 9.869582496855773e+17

# %%
import numpy as np
data = np.load('dataset/layout_000001.npz')
print(data.files)          # should show 'x', 'y', maybe 'penalty', 'moved_flag'
print(data['x'].shape, data['y'].shape)
# Out:
# ['config_json', 'best_sol', 'penalty', 'cg_x', 'cg_y', 'num_components', 'element_names', 'masses', 'lengths', 'widths', 'insert_diams', 'is_back_side', 'panel_width', 'panel_height', 'border_spacing', 'clearance', 'flat_offsets', 'offset_counts', 'offset_indices', 'clearance_dirs', 'req_d_matrix', 'lower_bounds', 'upper_bounds']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 data = np.load('dataset/layout_000001.npz')
#       3 print(data.files)          # should show 'x', 'y', maybe 'penalty', 'moved_flag'
# ----> 4 print(data['x'].shape, data['y'].shape)
#
# File ~/Desktop/isro/layout_env/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:243, in NpzFile.__getitem__(self, key)
#     241     key = self._files[key]
#     242 except KeyError:
# ...
